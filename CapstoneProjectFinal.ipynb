# %% [markdown]
# # Final Capstone Project: Week 2
#
# ### Best Tutoring Service Locations Search
#
# 1. Introduction/Business Problem:
# Our goal is to ﬁnd the best location (areas/neighborhood) to start a tutoring service business in Ontario (Brampton), Canada. We need to ﬁnd areas with the schools with the largest enrollment as well as the lowest number of existing tutoring services (oﬀered nearby). The presence of schools determines existence of clients (students), the lack of existing tutoring services means a lack of competition for our prospective business owner. We also consider schools with a lower percentage of low-income families or a higher percentage of parents with university education which indicates that parents can aﬀord the tutorial services offered by the business owner. The process is to specialize, ﬁltering for Elementary or Secondary School, cities, and such.
#
# 2. Data:
# Source data is publicly available from the government of Ontario at the following link: https://www.ontario.ca/data/schoolinformation-and-student-demographics
# This data-set provides info about almost 5,000 schools all over Ontario, with the location coordinates and the number of students enrolled. Using the location data along with foursquare, a venue search engine, we may search for tutoring services near each of the schools. These will be categorized by the number of services nearby.

# %% [markdown]
# ## These are the libraries and functions we will use
#
# Searching Foursquare, extracting the relevant information from the resulting JSON, and plotting points onto a Leaflet map.

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium as fol
import pandas as pd
pd.options.display.max_columns= None
pd.set_option('display.max_colwidth', -1)
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import requests

def foursq_search(lats, lngs, query, limit=50, radius=3000 ):
    '''Search Foursquare at the interable coordinates [lats/lngs] given for the given [query]. 
    Return a list of jsons containing the results'''
    res=[]
    CLIENT_ID = 'UEWJN1IMFLFWQ2VDYFEAZX00HEPRZQCEK14TB5YWKZWGUDMA' # your Foursquare ID
    CLIENT_SECRET = 'F3BLNCIFGVYQSXLFURGE1LAPXEQX53BAEYKGWMILZAYXEU2C' # your Foursquare Secret
    VERSION = '20180605' # Foursquare API version

    base_url= 'https://api.foursquare.com/v2/venues/search?'
    
    for lat, lng in zip( lats, lngs):
        url= base_url + '&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&query={}&limit={}'.format(
                CLIENT_ID,
                CLIENT_SECRET,
                VERSION,
                lat,
                lng,
                radius,
                query,
                limit)
        try:
            result= requests.get(url).json()
        except:
            print('Error searching: {},{}. Assigning 0 venues.'.format(lat, lng))
            result= { 'response':{} }
        res.append(result)
    return res

def extract_results( results, amt=[], venues=[], unique_venues= [], specs= [] , excls= []):
    '''Extract/update from each json in the list of [results] the [amt] of venues and the [unique_venues]. 
    Optionally return only venues containing a string in the [specs] list and not one in the [exclude] list.
    Return a list with the number of venues in each result and a dataframe with the lat/lng/name of each unique venue'''

    for i, result in enumerate( results ):
        
        if len( amt ) < len( results ): 
            amt.append( 0 )
        
        # non-empty result
        if result['response'] != {}:
                
            # iterate through the venues in the response
            for venue in result['response']['venues']:

                # make a tuple of the lat/lng/name of each venue
                temp_venue= ( venue['location']['lat'], venue['location']['lng'], venue['name'] )

                # if the specifics list is nonempty check that at least one of the strings is in the venue name
                # if there are specifics and they aren't in the venue name move on to the next venue
                # similar process if a string in the inclusion list is present
                if ( specs != [] ) & ( np.array([spec.lower() in temp_venue[2].lower() for spec in specs] ).sum() == 0): 
                    continue
                if ( excls != [] ) & ( np.array([excl.lower() in temp_venue[2].lower() for excl in excls] ).sum() != 0): 
                    continue

                amt[i]+= 1 
                
                # if we haven't encountered this venue, add it to our unique venue list
                if not temp_venue in unique_venues: 
                    unique_venues+= [ temp_venue ]

                    
    return amt, unique_venues



def plot_points( lats, lngs , radii=[], colors=[], labels=[], opacities=[], toner=False,zoom=12, prev_map= None):
    '''Plot/add coordinates [lats/lngs] with optional [radii],[colors],[labels]. Optinally update a [prev_map].
    Return a map.'''
    
    pt_amt= len( lats )
    
    # check initial conditions    
    make_popups= lambda labels: [ fol.Popup( l, parse_html=True) for l in labels ] \
                                if len( labels ) == pt_amt \
                                else [None] * pt_amt
    check_radii= lambda radii: radii if len( radii ) == pt_amt else [1] * pt_amt
    check_colors= lambda colors: colors if len( colors ) == pt_amt else ['black'] * pt_amt
    check_opacities= lambda opacities: opacities if len( opacities ) == pt_amt else [1] * pt_amt
    
    popups= make_popups( labels )
    radii= check_radii( radii )
    colors= check_colors( colors )
    opacities= check_opacities( opacities )
    
    # if there was no previous map make a new one
    if prev_map == None:
        center= [ lats.mean(), lngs.mean() ]
        tiles= 'Stamen Toner' if toner else 'OpenStreetMap'
        prev_map= fol.Map( location=center, zoom_start=zoom, control_scale=True, tiles=tiles)
        
    for lat, lng, r, color, op, popup in zip(lats, lngs, radii, colors, opacities, popups):
        fol.Circle(
            location=[lat,lng],
            radius=r,
            color=color,
            popup= popup,
            fill=True,
            fill_color=color,
            fill_opacity=op
        ).add_to(prev_map)

    return prev_map

# %% [markdown]
# ### Import raw data & Data Preparation
# Source data is publicly available from the government of Ontario at the following link: https://www.ontario.ca/data/schoolinformation-and-student-demographics
# This data-set provides info about almost 5,000 schools all over Ontario, with the location coordinates and the number of students enrolled. Using the location data along with foursquare, a venue search engine, we may search for tutoring services near each of the schools. These will be categorized by the number of services nearby.
#
# Our Data Source: https://files.ontario.ca/opendata/sif_data_table_2015_2016_en.xlsx

# %%
# ontario has free data
data= pd.read_excel('https://files.ontario.ca/opendata/sif_data_table_2015_2016_en.xlsx')

# drop what seem to be keys as well as irrelevant/redundant columns
data.drop(['Board Number','Board Type','School Number', 'Province', 'Municipality','School Website','Board Website','Building Suite','P.O. Box'],axis=1,inplace=True)

# title case the city column for ease
data['City'] = data['City'].apply(lambda x: x.title())

# take only english speaking elementary and secondary schools into account
data= data[ data['School Language'] == 'English' ]
data.drop('School Language', axis=1, inplace=True)

data= data[ (data['School Level'] == 'Elementary') | (data['School Level'] == 'Secondary') ]
data.drop('School Level', axis=1, inplace=True)

print('The data has {} rows & {} cols.'.format(data.shape[0],data.shape[1]))

data.head()
# Out:
# The data has 4449 rows & 42 cols.
#    Board Name                                   School Name School Type  \
# 0  Algoma DSB  Algoma Education Connection Secondary School  Public
# 1  Algoma DSB  Anna McCrea Public School                     Public
# 2  Algoma DSB  Arthur Henderson Public School                Public
# 3  Algoma DSB  Ben R McMullin Public School                  Public
# 4  Algoma DSB  Blind River Public School                     Public
#
#   School Special Condition Code Grade Range               Street  \
# 0  Alternative                   9-12        550 NORTHERN AVENUE
# 1  Not applicable                JK-8        250 Mark
# 2  Not applicable                JK-8        2 Henderson
# 3  Not applicable                JK-8        24 Paradise
# 4  Not applicable                JK-8        19 Hanes
#
#                City Postal Code  Phone Number    Fax Number  Enrolment  \
# 0  Sault Ste. Marie  P6B4J4      NaN           NaN           236.0
# 1  Sault Ste Marie   P6A3M7      705-945-7106  705-945-7221  168.0
# 2  Bruce Mines       P0R1C0      705-785-3483  705-785-3220  101.0
# 3  Sault Ste Marie   P6B5K2      705-945-7108  705-945-7205  189.0
# 4  Blind River       P0R1B0      705-356-7752  705-356-0271  187.0
#
#    Latitude  Longitude  \
# 0  46.53477 -84.30772
# 1  46.50593 -84.28732
# 2  46.30183 -83.78020
# 3  46.52455 -84.29804
# 4  46.18454 -82.95760
#
#   Percentage of Students Whose First Language Is Not English  \
# 0  NaN
# 1  SP
# 2  SP
# 3  SP
# 4  SP
#
#   Percentage of Students Whose First Language Is Not French  \
# 0  100
# 1  100
# 2  100
# 3  100
# 4  100
#
#   Percentage of Students Who Are New to Canada from a Non-English Speaking Country  \
# 0  NaN
# 1  SP
# 2  NaN
# 3  SP
# 4  SP
#
#   Percentage of Students Who Are New to Canada from a Non-French Speaking Country  \
# 0  NaN
# 1  SP
# 2  NaN
# 3  SP
# 4  SP
#
#   Percentage of Students Receiving Special Education Services  \
# 0  18.6
# 1  15.5
# 2  11.9
# 3  13.8
# 4  23
#
#   Percentage of Students Identified as Gifted  \
# 0  NaN
# 1  NaN
# 2  NaN
# 3  SP
# 4  NaN
#
#   Percentage of Grade 3 Students Achieving the Provincial Standard in Reading  \
# 0  NaN
# 1  0.77
# 2  0.38
# 3  0.44
# 4  0.5
#
#    Change in Grade 3 Reading Achievement Over Three Years  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
#   Percentage of Grade 3 Students Achieving the Provincial Standard in Writing  \
# 0  NaN
# 1  0.58
# 2  0.31
# 3  0.38
# 4  0.36
#
#    Change in Grade 3 Writing Acheivement Over Three Years  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
#   Percentage of Grade 3 Students Achieving the Provincial Standard in Mathematics  \
# 0  NaN
# 1  0.81
# 2  0.46
# 3  0.44
# 4  0.5
#
#    Change in Grade 3 Mathematics Achievement Over Three Years  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
#   Percentage of Grade 6 Students Achieving the Provincial Standard in Reading  \
# 0  NaN
# 1  0.8
# 2  N/D
# 3  0.74
# 4  0.52
#
#    Change in Grade 6 Reading Achievement Over Three Years  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
#   Percentage of Grade 6 Students Achieving the Provincial Standard in Writing  \
# 0  NaN
# 1  0.67
# 2  N/D
# 3  0.65
# 4  0.65
#
#    Change in Grade 6 Writing Acheivement Over Three Years  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
#   Percentage of Grade 6 Students Achieving the Provincial Standard in Mathematics  \
# 0  NaN
# 1  0.53
# 2  N/D
# 3  0.22
# 4  0.3
#
#    Change in Grade 6 Mathematics Achievement Over Three Years  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
#   Percentage of Grade 9 Students Achieving the Provincial Standard in Academic Mathematics  \
# 0  N/D
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
#    Change in Grade 9 Academic Mathematics Acheivement Over Three Years  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
#   Percentage of Grade 9 Students Achieving the Provincial Standard in Applied Mathematics  \
# 0  N/R
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
#    Change in Grade 9 Applied Mathematics Achievement Over Three Years  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
#   Percentage of Students That Passed the Grade 10 OSSLT on Their First Attempt  \
# 0  N/R
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
#    Change in Grade 10 OSSLT Literacy Achievement Over Three Years  \
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
#   Percentage of Children Who Live in Low-Income Households  \
# 0  33.88
# 1  8.1
# 2  13.42
# 3  27.9
# 4  22.36
#
#   Percentage of Students Whose Parents Have Some Unviersity Education  \
# 0  SP
# 1  20.97
# 2  SP
# 3  14.95
# 4  10.7
#
#    Percentage of JK-Grade 3 Classes With 20 Students or Fewer  \
# 0 NaN
# 1  1.0
# 2  0.0
# 3  1.0
# 4  1.0
#
#    Percentage of JK-Grade 3 Classes With 23 Students or Fewer Extract Date
# 0 NaN                                                          Dec-04-17
# 1  1.0                                                         Dec-04-17
# 2  1.0                                                         Dec-04-17
# 3  1.0                                                         Dec-04-17
# 4  1.0                                                         Dec-04-17

# %% [markdown]
# ### Clean up our data into the dataframe we will use
# Create a dataframe including the most useful columns from the original data, we also get rid of null values and replace them with the average for the column.

# %%
# extract only the columns we want
cols= ['School Name','Enrolment','Latitude','Longitude','City']
school_df= data[cols].copy()

#these are the numerical portions of the original data
pct_df= data.iloc[:,-5:-3]

school_df= pd.concat( [school_df, pct_df], axis=1 , sort=True )

# change the column names to make them easier to work with
school_df.columns= ['school','enrol','lat','lng','city','pct_low_income', 'pct_uni_parents']

# drop all entries with null in any of the specified columns
school_df.dropna(subset= ['school','enrol','lat','lng','city'], inplace=True)

# make null entries the average for the numerical data
for col in school_df:
    if not col in ['school', 'enrol', 'lat', 'lng' ,'city']:
        avg= 0
        num_entries= 0
        for val in school_df[col].values:
            if (not val in ['SP','N/R','N/D']) & (val == val):
                avg+= val
                num_entries+= 1
        avg= avg / num_entries
        school_df[col].replace( ['SP','N/R','N/D', np.nan], avg, inplace=True )

print('The schools dataframe has {} rows & {} cols.'.format(school_df.shape[0],school_df.shape[1]))
school_df.head()
# Out:
# The schools dataframe has 4357 rows & 7 cols.
#                                          school  enrol       lat       lng  \
# 0  Algoma Education Connection Secondary School  236.0  46.53477 -84.30772
# 1  Anna McCrea Public School                     168.0  46.50593 -84.28732
# 2  Arthur Henderson Public School                101.0  46.30183 -83.78020
# 3  Ben R McMullin Public School                  189.0  46.52455 -84.29804
# 4  Blind River Public School                     187.0  46.18454 -82.95760
#
#                city  pct_low_income  pct_uni_parents
# 0  Sault Ste. Marie  33.88           24.372899
# 1  Sault Ste Marie   8.10            20.970000
# 2  Bruce Mines       13.42           24.372899
# 3  Sault Ste Marie   27.90           14.950000
# 4  Blind River       22.36           10.700000

# %% [markdown]
# ### Narrow our scope to Brampton

# %%
brampton_df= school_df[ school_df.city == 'Brampton' ].copy()

# drop columns we dont need
brampton_df.drop('city', axis=1,inplace=True)
brampton_df.reset_index(drop=True, inplace=True)

print('There are {} schools in Brampton'.format(brampton_df.shape[0]))
brampton_df.head()
# Out:
# There are 169 schools in Brampton
#                                         school   enrol       lat       lng  \
# 0  Bishop Francis Allen Catholic School         358.0   43.66624 -79.74619
# 1  Cardinal Ambrozic Catholic Secondary School  1332.0  43.78772 -79.68312
# 2  Cardinal Leger Secondary School              1118.0  43.68409 -79.75050
# 3  Cardinal Newman Catholic School              504.0   43.72155 -79.69919
# 4  Father C W Sullivan Catholic School          301.0   43.70595 -79.74661
#
#    pct_low_income  pct_uni_parents
# 0  23.25           29.09
# 1  16.58           31.78
# 2  20.87           11.33
# 3  22.76           15.02
# 4  17.87           11.46

# %% [markdown]
# ## Search FourSquare for tutoring services near schools
# We make three searches: tutors, math and learn.

# %%
# get the foursquare results for searches 'tutor', 'math' and 'learn'

amt= []
unique_tutors= []

print('Working.. 1/3')
results1= foursq_search(brampton_df.lat, brampton_df.lng, query='tutor')
amt, unique_tutors= extract_results(results1)

print('Working.. 2/3')
results2= foursq_search(brampton_df.lat, brampton_df.lng, query='math')
amt, unique_tutors= extract_results(results2, amt=amt, unique_venues=unique_tutors, specs=['math ', 'mathematics', 'mathnasium'])

print('Working.. 3/3')
results3= foursq_search(brampton_df.lat, brampton_df.lng, query='learn')
amt, unique_tutors= extract_results(results3, amt=amt, unique_venues=unique_tutors , specs=[ 'oxford', 'sylvan'])
print('Done!')

# make a column for the number of services near each school
brampton_df['tutor_services']= amt

# this is a measure of how good the school is based on how many students are in it and the number of services near it
brampton_df['enrol_tutors_ratio']= brampton_df.enrol / (brampton_df.tutor_services + 1 )

print('Results collected.')
brampton_df.head()
# Out:
# Working.. 1/3
# Working.. 2/3
# Working.. 3/3
# Done!
# Results collected.
#                                         school   enrol       lat       lng  \
# 0  Bishop Francis Allen Catholic School         358.0   43.66624 -79.74619
# 1  Cardinal Ambrozic Catholic Secondary School  1332.0  43.78772 -79.68312
# 2  Cardinal Leger Secondary School              1118.0  43.68409 -79.75050
# 3  Cardinal Newman Catholic School              504.0   43.72155 -79.69919
# 4  Father C W Sullivan Catholic School          301.0   43.70595 -79.74661
#
#    pct_low_income  pct_uni_parents  tutor_services  enrol_tutors_ratio
# 0  23.25           29.09            3               89.500000
# 1  16.58           31.78            1               666.000000
# 2  20.87           11.33            2               372.666667
# 3  22.76           15.02            1               252.000000
# 4  17.87           11.46            2               100.333333

# %% [markdown]
# ### Create a dataframe for the unique tutoring services

# %%
#make a dataframe with the information for each unique service found
unique_tutors_df= pd.DataFrame.from_records(unique_tutors, columns=['lat','lng','name'])
unique_tutors_df
# Out:
#          lat        lng                               name
# 0  43.682367 -79.767512  Impel Tutors
# 1  43.772775 -79.660586  Learna Tutoring
# 2  43.666087 -79.737461  Academy for Mathematics & Science
# 3  43.715216 -79.723803  Kumon Math & Reading Centre
# 4  43.676515 -79.823418  UCMAS Mental Math School
# 5  43.639050 -79.716064  academy for mathematics & english
# 6  43.658689 -79.726444  Oxford Learning Centre
# 7  43.760366 -79.728131  Oxford Learning Centre
# 8  43.681636 -79.816006  Oxford Learning

# %% [markdown]
# ## Mapping tutors and schools

# %%
tut_amt= unique_tutors_df.shape[0]

# make yellow circles signifying the effective radius of each tutoring services
area_map= plot_points( unique_tutors_df.lat, 
                         unique_tutors_df.lng,
                         [3000] * tut_amt,
                         ['yellow'] * tut_amt,
                         opacities= [0.1] * tut_amt )

# add the tutoring services to the map
tut_map= plot_points( unique_tutors_df.lat, 
                         unique_tutors_df.lng,
                         [100] * tut_amt,
                         ['red'] * tut_amt, 
                         unique_tutors_df.name, 
                         prev_map=area_map )


# add the schools to the map
sch_amt= brampton_df.shape[0]
labels= [ name + ' : {} tutoring services'.format(tut) for name, tut in zip( brampton_df.school, brampton_df.tutor_services ) ]

full_map= plot_points( brampton_df.lat, 
                         brampton_df.lng,
                         [80] * sch_amt,
                         ['blue'] * sch_amt, 
                         labels,
                         brampton_df.tutor_services / brampton_df.tutor_services.max(),
                         prev_map=tut_map )

full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Using K-Means Algorithm to Cluster Schools

# %%
# make a temporary dataframe to extract the data to feed the K-Means algorithm
cols= ['school', 'lat', 'lng']
kmeans_tempdf= brampton_df.drop(cols, axis=1)
# ensure there are no null values
kmeans_tempdf.head()
# Out:
#     enrol  pct_low_income  pct_uni_parents  tutor_services  enrol_tutors_ratio
# 0  358.0   23.25           29.09            3               89.500000
# 1  1332.0  16.58           31.78            1               666.000000
# 2  1118.0  20.87           11.33            2               372.666667
# 3  504.0   22.76           15.02            1               252.000000
# 4  301.0   17.87           11.46            2               100.333333

# %% [markdown]
# ## Normalize our data

# %%
# fit our data to emulate a standard normal distribution to make sure all factors are equal
X= np.nan_to_num( kmeans_tempdf.values )
X= StandardScaler().fit_transform(X)
print(X[:5])
print('Data Standardized.')
# Out:
# [[-0.7695138   1.75701226  0.00509834  1.4828575  -0.86579394]
#  [ 1.87295179 -0.02631759  0.22574879 -0.49819323  1.27867857]
#  [ 1.292369    1.12068167 -1.45168676  0.49233213  0.18753326]
#  [-0.37341526  1.62600302 -1.14901013 -0.49819323 -0.26132424]
#  [-0.92415501  0.31858429 -1.44102336  0.49233213 -0.82549596]]
# Data Standardized.

# %% [markdown]
# ## Create the ML model and fit it with our data

# %%
clusters= 9

# run k-means on the data separated
kmeans= KMeans(init='k-means++', n_clusters=clusters, n_init= 12)
kmeans.fit(X)
print('Model fit with data.')
# Out:
# Model fit with data.

# %% [markdown]
# ## We've got the clusters!

# %%
# make a column for the clusters given to each school
brampton_df['cluster']= kmeans.labels_
brampton_df[['school','cluster']].head()
# Out:
#                                         school  cluster
# 0  Bishop Francis Allen Catholic School         7
# 1  Cardinal Ambrozic Catholic Secondary School  3
# 2  Cardinal Leger Secondary School              3
# 3  Cardinal Newman Catholic School              4
# 4  Father C W Sullivan Catholic School          8

# %% [markdown]
# ## Analyzing the Clusters

# %%
color_map= [ 'red','blue','orange','black','lime','green','pink','purple','brown' ]

# show the number of schools in each cluster as well as the mean ratio for each 
view= brampton_df.groupby('cluster').mean().reset_index()
view['color']= view.cluster.apply( lambda c: color_map[c].title() )
view['count'] = brampton_df.cluster.value_counts(sort=False)

cols= view.columns.tolist()
cols= cols[-2:] + [cols[-3]] + [cols[1]] + cols[4:-3]
view= view[cols]

view.columns= [ s.replace('_', ' ').title() for s in view.columns ]
view.set_index('Color', inplace=True)
view.index.name= None
view.sort_values('Enrol Tutors Ratio', ascending=False ).apply( lambda x: round(x, 2), axis=1)
# Out:
#         Count  Enrol Tutors Ratio    Enrol  Pct Low Income  Pct Uni Parents  \
# Pink    6.0    1311.08             1468.00  17.11           19.63
# Orange  14.0   694.43              694.43   13.27           37.31
# Black   15.0   496.68              1413.00  19.26           17.88
# Green   27.0   352.70              677.22   14.23           42.01
# Red     20.0   278.62              387.55   15.21           23.36
# Lime    17.0   210.23              427.12   23.15           22.09
# Blue    28.0   202.47              648.96   13.75           40.95
# Brown   22.0   133.28              392.68   17.15           16.84
# Purple  20.0   107.56              430.25   19.85           25.18
#
#         Tutor Services
# Pink    0.17
# Orange  0.00
# Black   2.00
# Green   0.93
# Red     0.50
# Lime    1.24
# Blue    2.29
# Brown   1.95
# Purple  3.00

# %% [markdown]
# ## Map the Clustered Schools

# %%
avgs= brampton_df.enrol_tutors_ratio
sch_amt= brampton_df.shape[0]
labels= [ name + ' : {} naive-expected students'.format( ratio ) for name, ratio in zip( brampton_df.school, avgs.apply(int) ) ]
color_map= [ 'red','blue','orange','black','lime','green','deeppink','purple','brown' ]

full_map= plot_points( brampton_df.lat, 
                         brampton_df.lng,
                         50 + 200*(( avgs - avgs.min() ) / (avgs.max() - avgs.min() )),
                         [ color_map[ cluster ] for cluster in brampton_df.cluster ], 
                         labels,
                         [0.5] * sch_amt )#, toner=True)

full_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Process Generalization
# Here are functions generalizing the steps we took earlier, now we can repeat the process for any Ontario city we desire.

# %%
def get_city_df(city):
    if isinstance(city, str):
        city_df= school_df[ school_df.city == city ].copy()
    elif isinstance(city, list):
        city_df= school_df[ school_df.city == city[0] ].copy()
        for c in city[1:]:
            city_df= pd.concat( [ city_df, school_df[ school_df.city == c ] ], axis=0 )
    else:
        return None
    # drop columns we dont need
    city_df.drop('city', axis=1,inplace=True)
    city_df.reset_index(drop=True, inplace=True)
    
    return city_df

def find_tutors(city_df, queries= ['tutor'] ):
    # get the foursquare results for searches 'tutor', 'math' and 'learn'
    ttl= len(queries)
    results= []
    for i, query in enumerate(queries):
        print('Working.. {}/{}'.format(i + 1, ttl))
        results.append(foursq_search(city_df.lat, city_df.lng, query=query ))
        
    print('Done!')
    
    return results
    
def parse_results(city_df, results, specs=[], excls=[] ):
    ttl= len( results )
    amt=[]
    unique_tutors=[]
    
    make_empties= lambda lst: lst if len(lst) == ttl else [[]] * ttl
        
    specs= make_empties(specs)
    excls= make_empties(excls)
    
    for i, result in enumerate(results):
        amt, unique_tutors= extract_results(result, amt=amt, unique_venues=unique_tutors, specs=specs[i], excls= excls[i] )
    # make a column for the number of services near each school
    city_df['tutor_services']= amt

    # this is a measure of how good the school is based on how many students are in it and the number of services near it
    city_df['enrol_tutors_ratio']= city_df.enrol / (city_df.tutor_services + 1 )
    
    unique_tutors_df= pd.DataFrame.from_records(unique_tutors, columns=['lat','lng','name'])

    return city_df, unique_tutors_df

def cluster_schools(city_df, clus= 9):
    cols= ['school', 'lat', 'lng']
    
    X= np.nan_to_num( city_df.drop(cols, axis=1).values )
    X= StandardScaler().fit_transform(X)

    # run k-means on the data separated
    kmeans= KMeans(init='k-means++', n_clusters=clus, n_init= 12)
    kmeans.fit(X)

    # make a column for the clusters given to each school
    city_df['cluster']= kmeans.labels_
    
    return city_df

def map_sch_tut(city_df, unique_tutors_df, clustered=False, zoom=12, prev_map=None):
    tut_amt= unique_tutors_df.shape[0]

    area_map= plot_points( unique_tutors_df.lat, 
                             unique_tutors_df.lng,
                             [3000] * tut_amt,
                             ['yellow'] * tut_amt,
                             opacities= [0.09] * tut_amt,
                             zoom=zoom,
                             prev_map=prev_map )

    #add the tutoring services to the map
    tut_map= plot_points( unique_tutors_df.lat, 
                             unique_tutors_df.lng,
                             [100] * tut_amt,
                             ['red'] * tut_amt, 
                             unique_tutors_df.name, 
                             prev_map=area_map )



    sch_amt= city_df.shape[0]
    labels= [ name + ' : {} Nearby Services'.format(tut) for name, tut in zip( city_df.school, city_df.tutor_services ) ]

    if not clustered:
        full_map= plot_points( city_df.lat, 
                                 city_df.lng,
                                 [80] * sch_amt,
                                 ['blue'] * sch_amt, 
                                 labels,
                                 city_df.tutor_services / city_df.tutor_services.max(),
                                 prev_map=tut_map )

        return full_map
    else:
        return map_clusters(city_df, prev_map= tut_map)

def map_clusters(city_df, prev_map=None):
    avgs= city_df.enrol_tutors_ratio
    sch_amt= city_df.shape[0]
    labels= [ name + ' : {} Naive-expected Students : {} Nearby Services'.format( ratio, tut ) for name, ratio, tut in zip( city_df.school, avgs.apply(int), city_df.tutor_services ) ]
    color_map= [ 'brown','blue','pink','red','purple','black','yellow','orange','green' ]

    full_map= plot_points( city_df.lat, 
                             city_df.lng,
                             50 + 200*(( avgs - avgs.min() ) / (avgs.max() - avgs.min() )),
                             [ color_map[ cluster ] for cluster in city_df.cluster ], 
                             labels,
                             [0.5] * sch_amt,
                             prev_map=prev_map )

    return full_map

# %% [markdown]
# ## Mississauga, Oakville, Brampton, Etobicoke and North York
# We will now do the quick version of our process to the combination of these cities.
# Get the schools:

# %%
cities= ['Brampton','Oakville','Etobicoke','Mississauga','North York']
city_df= get_city_df(cities)
print('There are {} schools in '.format(city_df.shape[0]), end='')
for i, cit in enumerate(cities):
    print(cit, end= ' ') if cit != cities[-1] else print('& {}.'.format(cit))
city_df.head()
# Out:
# There are 610 schools in Brampton Oakville Etobicoke Mississauga & North York.
#                                         school   enrol       lat       lng  \
# 0  Bishop Francis Allen Catholic School         358.0   43.66624 -79.74619
# 1  Cardinal Ambrozic Catholic Secondary School  1332.0  43.78772 -79.68312
# 2  Cardinal Leger Secondary School              1118.0  43.68409 -79.75050
# 3  Cardinal Newman Catholic School              504.0   43.72155 -79.69919
# 4  Father C W Sullivan Catholic School          301.0   43.70595 -79.74661
#
#    pct_low_income  pct_uni_parents
# 0  23.25           29.09
# 1  16.58           31.78
# 2  20.87           11.33
# 3  22.76           15.02
# 4  17.87           11.46

# %% [markdown]
# ## Search for tutoring services:

# %%
queries= ['tutors', 'math', 'learning' ]
results= find_tutors(city_df, queries)
results
# Out:
# Working.. 1/3
# Working.. 2/3
# Working.. 3/3
# Done!
# [[{'meta': {'code': 200, 'requestId': '5c8c5da3dd57973af0179f30'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2483,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702883',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da3db04f50daed994bf'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da36a607168d030dc32'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 1382,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702883',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da4f594df7cde875ca5'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da4f594df7cdf7b4840'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 3118,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702884',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da4f594df7cdf7b4959'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da51ed219672b318f0d'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da54c1f6746f416f44f'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da5351e3d34d5c6063a'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da5db04f50dad04a54e'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da66a607168cec6538a'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da6db04f50daed9a0f2'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da64c1f67470e562901'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da7351e3d34d93ae6f5'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da71ed21967292a281f'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 1025,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702887',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da79fb6b7539a52781e'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da7dd57973aad482f2e'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 1682,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702888',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da8f594df7cdd538940'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da8dd57973af017b4f3'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da89fb6b753d6832173'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da9db04f50dad04b22c'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da91ed219672b31a085'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da9dd57973af017b930'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 1913,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702889',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5da9dd57973aad48371e'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5daa4434b97bb5ac9687'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2714,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702890',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5daaf594df7ce0115569'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2775,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702890',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5daadb04f50db3148616'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2648,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702890',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dabdb04f50db3148733'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dab6a607168d030fb0a'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2525,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702891',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dabdd57973ab04c0c69'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dab4c1f6746bd6ffb51'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dacdb04f50db110a6ea'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dacdb04f50daed9b9f0'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5daddb04f50db3148f24'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dad351e3d34d93b000a'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 1086,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702893',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5daddd57973aca8b605b'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dad6a607168d5de6d44'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5daedb04f50db110ae54'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dae4434b97c1b7d5174'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dae6a607168cec676bd'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2287,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702894',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5daf4c1f674728532359'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 1089,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702895',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5daf1ed219672cc754e3'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 1998,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702895',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5daff594df7cd9e88577'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5daf4434b97bf75b0654'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db0351e3d34d93b0ba9'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db0f594df7cde878e35'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db09fb6b7536a32e29c'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2714,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702896',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db19fb6b753bcea48b0'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db16a607168d2b95c21'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db16a607168d0311442'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db19fb6b7539a52a174'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 3101,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702898',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db21ed219672cc76099'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db2db04f50db0907ba6'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db21ed219672d59a025'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 3389,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702898',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db3db04f50daed9d434'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db3dd57973af017e029'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 1900,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702899',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db39fb6b753bcea535d'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db49fb6b7539a52a98b'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db49fb6b753bcea55c2'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db44c1f6746be193e8d'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db5351e3d34d93b1efd'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 957,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702901',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db5dd57973af017e7fd'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db5db04f50dad04e484'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db5f594df7cdb643844'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db6dd57973aad48684e'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2312,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702902',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db66a607168d031282a'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db64c1f6746bc478236'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db71ed219672d59b143'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db7f594df7cde87a9c7'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db71ed21967292a68de'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db84c1f6746be194b67'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db8351e3d34db0cb699'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db8dd57973aad487165'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 1842,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702904',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db89fb6b753d68361df'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2226,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702904',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db91ed219672d59b907'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db9db04f50daed9ecb0'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5db96a607168d4c39be1'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dba1ed219672f3426ee'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 3069,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702906',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dba9fb6b753bcea6d94'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dba1ed219672b31e546'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbaf594df7cdf7ba20b'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbb9fb6b7536994ceb0'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 3753,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702907',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbb6a607168d5dea338'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2101,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702907',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbb1ed219672a832915'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbcdb04f50db110e59f'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbc351e3d34db0cc6ef'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbc6a607168d4c3a7a0'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbd4c1f6746f41752f4'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbdf594df7cdb6455b3'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbddb04f50db090a7b4'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbd9fb6b7536994d8ea'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbe351e3d34d6277ab0'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbe9fb6b7536a331819'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbef594df7cdb645b1e'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbef594df7cde87c6f4'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbf6a607168cf3dba89'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbf1ed219672d59d13c'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 903,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702911',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dbf6a607168d2b9952f'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc0db04f50daeda0657'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 3002,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702912',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc09fb6b7539a52d9f0'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc0351e3d34d7adb01b'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc1f594df7cdd53eaff'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc1db04f50db110f93d'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc1dd57973af0181774'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc19fb6b753bcea8a86'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc2dd57973af01819a0'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc29fb6b7539a52e160'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2050,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702914',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc2db04f50db314e45f'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc3f594df7cdb646b57'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc3db04f50db11100d0'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc36a607168cec6c7f4'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2602,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702915',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc4db04f50dad051c77'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc49fb6b753b4d73ca3'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc4db04f50daf5247fb'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 3470,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702916',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc4351e3d34d93b5c2c'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc59fb6b753b4d73fe2'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc54434b97bb782cfa5'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2235,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702917',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc5351e3d34d7adc364'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc6db04f50db1110b9c'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc69fb6b753d68395db'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc6f594df7cdf7bce70'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc6dd57973aaf66572b'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 2760,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702918',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc7f594df7ce011c5f0'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc74434b97bf75b628f'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc74c1f67472853846b'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 746,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702919',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc8f594df7cd9e8e594'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 3170,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702920',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc8db04f50db314fa1b'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc86a607168d5ded603'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc84c1f6746bc47c7b3'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc96a607168cf3de126'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc96a607168cec6deca'},
#    'response': {'venues': []}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dc94434b97bb782e0cf'},
#    'response': {'venues': [{'id': '57ad6981498e0d78c3f6cd84',
#       'name': 'Impel Tutors',
#       'location': {'address': '43 McMurchy Ave N',
#        'crossStreet': 'brompton',
#        'lat': 43.68236694270353,
#        'lng': -79.76751208305359,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 43.68236694270353,
#          'lng': -79.76751208305359}],
#        'distance': 1073,
#        'postalCode': 'L6X 1X4',
#        'cc': 'CA',
#        'city': 'Ontario',
#        'state': 'ON',
#        'country': 'Canada',
#        'formattedAddress': ['43 McMurchy Ave N (brompton)',
#         'Ontario ON L6X 1X4',
#         'Canada']},
#       'categories': [{'id': '4bf58dd8d48988d1a8941735',
#         'name': 'General College & University',
#         'pluralName': 'General Colleges & Universities',
#         'shortName': 'Education',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#          'suffix': '.png'},
#         'primary': True}],
#       'referralId': 'v-1552702921',
#       'hasPerk': False}]}},
#   {'meta': {'code': 200, 'requestId': '5c8c5dca1ed219672b3220f3'},
# ...
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f974c1f67470e5de002'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f976a607168d5e60619'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f97351e3d34d7b500bd'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f989fb6b753699c3210'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f984434b97bf76296af'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f98f594df7cdf83061b'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f98db04f50db1184bc6'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f994434b97bcbc705c8'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f99db04f50db09807e4'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f99f594df7ce01904b3'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9a351e3d34d62edc84'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9a9fb6b753d68ad9bc'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9adb04f50dad0c6855'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9b9fb6b7539a5a36da'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9b4434b97bb78a1a58'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9b1ed2196729314554'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9b6a607168d038b066'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9c1ed219672b38b6f2'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9c351e3d34d5cdd194'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9c6a607168d4cb1789'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9c4c1f6746bd77b141'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9d4c1f6747285acc14'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9d6a607168d038b69c'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9df594df7cde8f3455'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9ddd57973aaef2ee41'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9edd57973aad4ff4b7'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9e1ed21967293150ba'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9edb04f50daee171e9'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9f9fb6b7539a5a4660'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9f6a607168d038bdd7'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9f6a607168d4cb22cb'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5f9f4434b97bb5b45e71'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa0f594df7cd9f03672'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa04434b97bcbc720db'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa0dd57973af01f82ea'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa0db04f50daf59aa0a'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa16a607168cf4532db'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa16a607168d5e62c35'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa1351e3d34d942c147'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa1351e3d34d7b527f4'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa2db04f50dad0c8558'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa2351e3d34d942c41e'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa29fb6b753699c5ac6'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa29fb6b753b4dea6b8'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa3f594df7cde8f49bf'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa3dd57973af01f8e13'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa34434b97bcbc72dc9'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa36a607168d038cf94'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa4db04f50db31c5c37'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa4db04f50db31c5d3e'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa4f594df7ce0192ed4'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa54434b97bf762c735'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa54434b97bb690527d'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa54c1f6746bd77d228'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa56a607168d2c11caf'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa5dd57973aaf6dc2d6'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa6dd57973aca932da2'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa6db04f50daf59bf79'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa6f594df7cdb6be8f5'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa69fb6b7539a5a64cc'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa7dd57973aad5017b4'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa7351e3d34d942d7a3'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa76a607168d5e644be'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa7db04f50daee19526'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa8351e3d34d5cdfee6'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa8dd57973aaef316b5'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa8dd57973af01fa1c0'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa89fb6b7539a5a6c11'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa94434b97bb6906179'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa99fb6b753bcf21be1'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fa94434b97bb78a5139'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5faa4434b97c1b852c45'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5faa9fb6b753bcf21efe'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5faadd57973af01fa985'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5faa1ed219672b38ef26'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fabdb04f50db11891d1'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fabf594df7cdb6bfb20'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fab1ed219672cce90e8'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fab9fb6b7539a5a77dd'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fac1ed219672cce9329'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fac4c1f6746bc4f44f5'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fac4c1f6747285b07db'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5facdb04f50db1189979'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fad6a607168d038f423'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fad1ed219672d60d689'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fae4434b97bb78a62ed'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fae4c1f6746f41f0648'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5faedb04f50db118a07b'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fafdd57973aad5036ba'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5faf4c1f6746bc4f50e0'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5faf351e3d34db1481e8'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5faf1ed219672d60df2a'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fb04434b97bcbc75eac'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fb04c1f6746be211b0e'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fb04434b97bb6907fc9'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fb1dd57973aad503eec'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fb1351e3d34d942ff50'},
#    'response': {}},
#   {'meta': {'code': 429,
#     'errorType': 'quota_exceeded',
#     'errorDetail': 'Quota exceeded',
#     'requestId': '5c8c5fb11ed219672b390a5e'},
#    'response': {}}]]

# %% [markdown]
# ## Extract the venues:

# %%
city_sch_tut, services= parse_results( city_df, results )
print('There are {} unique relevant results.'.format( len( services ) ))
print(services.name[:5])
city_sch_tut.head()
# Out:
# There are 1 unique relevant results.
# 0    Impel Tutors
# Name: name, dtype: object
#                                         school   enrol       lat       lng  \
# 0  Bishop Francis Allen Catholic School         358.0   43.66624 -79.74619
# 1  Cardinal Ambrozic Catholic Secondary School  1332.0  43.78772 -79.68312
# 2  Cardinal Leger Secondary School              1118.0  43.68409 -79.75050
# 3  Cardinal Newman Catholic School              504.0   43.72155 -79.69919
# 4  Father C W Sullivan Catholic School          301.0   43.70595 -79.74661
#
#    pct_low_income  pct_uni_parents  tutor_services  enrol_tutors_ratio  \
# 0  23.25           29.09            1               179.0
# 1  16.58           31.78            0               1332.0
# 2  20.87           11.33            1               559.0
# 3  22.76           15.02            0               504.0
# 4  17.87           11.46            1               150.5
#
#    cluster
# 0  2
# 1  7
# 2  2
# 3  0
# 4  2

# %% [markdown]
# ## Filter our results:
# We look through the results and create specifications and exclusions to re-parse the results. These are done manually and could be automated.

# %%
specs= [[], ['math ', 'mathstat', 'mathematics'], []]
excls= [    [],
           [ 'copy room', 'humber', 'library', 'class', 'department' ],
           [ 'acend', 'elearning', 'e-learning' ,'playground','pavilion','disabilities',
               'early', 'teksource', 'build','rider','network','adult',
               'enabled', 'york','library','solutions','scotiabank',
               'tykes','child','bmo','international','agincourt','code','engage'
               'e-learning','music','ocadu','rbc','research','smw','ryerson',
               'reiki','employee', 'path' ,'otf','thornhill', 'day care', 'golf', 
                'humber', 'finance','gems'] ]

city_sch_tut, services= parse_results( city_df, results , specs=specs, excls=excls)
print('There are {} unique relevant results.'.format( len( services ) ))
print(services.name[:5])
city_sch_tut.head()
# Out:
# There are 1 unique relevant results.
# 0    Impel Tutors
# Name: name, dtype: object
#                                         school   enrol       lat       lng  \
# 0  Bishop Francis Allen Catholic School         358.0   43.66624 -79.74619
# 1  Cardinal Ambrozic Catholic Secondary School  1332.0  43.78772 -79.68312
# 2  Cardinal Leger Secondary School              1118.0  43.68409 -79.75050
# 3  Cardinal Newman Catholic School              504.0   43.72155 -79.69919
# 4  Father C W Sullivan Catholic School          301.0   43.70595 -79.74661
#
#    pct_low_income  pct_uni_parents  tutor_services  enrol_tutors_ratio  \
# 0  23.25           29.09            1               179.0
# 1  16.58           31.78            0               1332.0
# 2  20.87           11.33            1               559.0
# 3  22.76           15.02            0               504.0
# 4  17.87           11.46            1               150.5
#
#    cluster
# 0  2
# 1  7
# 2  2
# 3  0
# 4  2

# %% [markdown]
# ## Here are the schools and tutoring services in Toronto:
#
# * Each blue marker represents a school.
# * Each red marker represents a tutoring service.
# * The yellow circles denote a 3km radius from each service. A 3km radius was used in our searches.

# %%
map_sch_tut(city_sch_tut, services, zoom=11 )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Now we use KMeans to cluster the schools

# %%
city_sch_tut= cluster_schools(city_sch_tut)
color_map= [ 'red','blue','orange','black','lime','green','pink','purple','brown' ]

# show the number of schools in each cluster as well as the mean ratio for each 
view= city_sch_tut.groupby('cluster').mean().reset_index()
view['color']= view.cluster.apply( lambda c: color_map[c].title() )
view['count'] = brampton_df.cluster.value_counts(sort=False)

cols= view.columns.tolist()
cols= cols[-2:] + [cols[-3]] + [cols[1]] + cols[4:-3]
view= view[cols]

view.columns= [ s.replace('_', ' ').title() for s in view.columns ]
view.set_index('Color', inplace=True)
view.index.name= None
view.sort_values('Enrol Tutors Ratio', ascending=False ).apply( lambda x: round(x, 2), axis=1)
# Out:
#         Count  Enrol Tutors Ratio    Enrol  Pct Low Income  Pct Uni Parents  \
# Green   27.0   1754.06             1754.06  19.61           24.29
# Orange  14.0   1089.96             1089.96  20.94           22.68
# Brown   22.0   731.83              731.83   14.85           40.33
# Red     20.0   590.04              590.04   12.08           61.43
# Lime    17.0   418.96              418.96   28.12           38.87
# Purple  20.0   364.92              364.92   15.34           41.34
# Pink    6.0    349.53              349.53   32.42           15.25
# Blue    28.0   317.44              317.44   18.41           21.38
# Black   15.0   274.39              548.78   18.39           24.17
#
#         Tutor Services
# Green   0.0
# Orange  0.0
# Brown   0.0
# Red     0.0
# Lime    0.0
# Purple  0.0
# Pink    0.0
# Blue    0.0
# Black   1.0

# %% [markdown]
# ## Finally here are the clustered schools along with the nearby services.
#
# Here the colours to look out for are GREEN and ORANGE. These schools have the least nearby services as well as the most expected students.

# %%
map_sch_tut(city_sch_tut, services, clustered=True, zoom=11)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
